# %%
import pandas as pd
import ast
# from bgg_refine import parse_link
# %run /path/to/bgg_refine.ipynb
# %run "C:/Users/cynst/Desktop/AI bootcamp class/Project 1/Project1/bgg_refine.ipynb"

# %%
# Read in the raw data
df = pd.read_csv('./data/cleaned.csv', low_memory=False)
len(df)
# Out:
# 119488

# %%
df.head()
# Out:
#        @type  @id            name  \
# 0  boardgame    1      Die Macher
# 1  boardgame    2    Dragonmaster
# 2  boardgame    3         Samurai
# 3  boardgame    4  Tal der Könige
# 4  boardgame    5         Acquire
#
#                                          description  minplayers  maxplayers  \
# 0  Die Macher is a game about seven sequential po...           3           5
# 1  Dragonmaster is a trick-taking card game based...           3           4
# 2  Samurai is set in medieval Japan. Players comp...           2           4
# 3  When you see the triangular box and the luxuri...           2           4
# 4  In Acquire, each player strategically invests ...           2           6
#
#                                                 poll  playingtime  \
# 0  [{'@name': 'suggested_numplayers', '@title': '...          240
# 1  [{'@name': 'suggested_numplayers', '@title': '...           30
# 2  [{'@name': 'suggested_numplayers', '@title': '...           60
# 3  [{'@name': 'suggested_numplayers', '@title': '...           60
# 4  [{'@name': 'suggested_numplayers', '@title': '...           90
#
#    minplaytime  maxplaytime  ...  seriescode issueindex  year  \
# 0          240          240  ...         NaN        NaN  1986
# 1           30           30  ...         NaN        NaN  1981
# 2           30           60  ...         NaN        NaN  1998
# 3           60           60  ...         NaN        NaN  1992
# 4           90           90  ...         NaN        NaN  1963
#
#                                  categories  \
# 0  ['Economic', 'Negotiation', 'Political']
# 1                  ['Card Game', 'Fantasy']
# 2         ['Abstract Strategy', 'Medieval']
# 3                               ['Ancient']
# 4        ['Economic', 'Territory Building']
#
#                                            mechanics  \
# 0  ['Alliances', 'Area Majority / Influence', 'Au...
# 1                                   ['Trick-taking']
# 2  ['Area Majority / Influence', 'Hand Management...
# 3  ['Action Points', 'Area Majority / Influence',...
# 4  ['Hand Management', 'Investment', 'Market', 'S...
#
#                                               family  \
# 0  ['Country: Germany', 'Digital Implementations:...
# 1  ['Components: Gems/Crystals', 'Creatures: Drag...
# 2  ['Components: Map (Continental / National scal...
# 3  ['Containers: Triangular Boxes', 'Country: Egy...
# 4  ['Components: 9 x 12 Grids', 'Digital Implemen...
#
#                   implementation                    designer  \
# 0                             []      ['Karl-Heinz Schmiel']
# 1  ['Indulgence', "Coup d'État"]  ['G. W. "Jerry" D\'Arcey']
# 2     ['Samurai: The Card Game']           ['Reiner Knizia']
# 3                             []       ['Christian Beierer']
# 4                             []             ['Sid Sackson']
#
#                                               artist  \
# 0  ['Bernd Brunnhofer', 'Marcus Gschwendtner', 'H...
# 1                                     ['Bob Pepper']
# 2                                ['Franz Vohwinkel']
# 3                                ['Thomas di Paolo']
# 4  ['Eric Hibbeler', "Scott O'Gara", 'Scott Okumu...
#
#                                            publisher
# 0  ['Hans im Glück', 'Moskito Spiele', 'Ediciones...
# 1      ['E. S. Lowe Company Inc.', 'Milton Bradley']
# 2  ['Fantasy Flight Games', 'Hans im Glück', '999...
# 3                                         ['KOSMOS']
# 4  ['3M', 'The Avalon Hill Game Co', 'Avalon Hill...
#
# [5 rows x 24 columns]

# %%
df.iloc[0,6]
# Out:
# "[{'@name': 'suggested_numplayers', '@title': 'User Suggested Number of Players', '@totalvotes': '136', 'results': [{'@numplayers': '1', 'result': [{'@value': 'Best', '@numvotes': '0'}, {'@value': 'Recommended', '@numvotes': '1'}, {'@value': 'Not Recommended', '@numvotes': '86'}]}, {'@numplayers': '2', 'result': [{'@value': 'Best', '@numvotes': '0'}, {'@value': 'Recommended', '@numvotes': '1'}, {'@value': 'Not Recommended', '@numvotes': '88'}]}, {'@numplayers': '3', 'result': [{'@value': 'Best', '@numvotes': '2'}, {'@value': 'Recommended', '@numvotes': '26'}, {'@value': 'Not Recommended', '@numvotes': '76'}]}, {'@numplayers': '4', 'result': [{'@value': 'Best', '@numvotes': '25'}, {'@value': 'Recommended', '@numvotes': '86'}, {'@value': 'Not Recommended', '@numvotes': '9'}]}, {'@numplayers': '5', 'result': [{'@value': 'Best', '@numvotes': '116'}, {'@value': 'Recommended', '@numvotes': '11'}, {'@value': 'Not Recommended', '@numvotes': '2'}]}, {'@numplayers': '5+', 'result': [{'@value': 'Best', '@numvotes': '1'}, {'@value': 'Recommended', '@numvotes': '0'}, {'@value': 'Not Recommended', '@numvotes': '62'}]}]}, {'@name': 'suggested_playerage', '@title': 'User Suggested Player Age', '@totalvotes': '31', 'results': {'result': [{'@value': '2', '@numvotes': '0'}, {'@value': '3', '@numvotes': '0'}, {'@value': '4', '@numvotes': '0'}, {'@value': '5', '@numvotes': '0'}, {'@value': '6', '@numvotes': '0'}, {'@value': '8', '@numvotes': '0'}, {'@value': '10', '@numvotes': '0'}, {'@value': '12', '@numvotes': '6'}, {'@value': '14', '@numvotes': '18'}, {'@value': '16', '@numvotes': '4'}, {'@value': '18', '@numvotes': '2'}, {'@value': '21 and up', '@numvotes': '1'}]}}, {'@name': 'language_dependence', '@title': 'Language Dependence', '@totalvotes': '49', 'results': {'result': [{'@level': '1', '@value': 'No necessary in-game text', '@numvotes': '37'}, {'@level': '2', '@value': 'Some necessary text - easily memorized or small crib sheet', '@numvotes': '5'}, {'@level': '3', '@value': 'Moderate in-game text - needs crib sheet or paste ups', '@numvotes': '7'}, {'@level': '4', '@value': 'Extensive use of text - massive conversion needed to be playable', '@numvotes': '0'}, {'@level': '5', '@value': 'Unplayable in another language', '@numvotes': '0'}]}}]"

# %%
 df["poll"] = df2["poll"].apply(parse_value)


def parse_poll(poll, key):
    poll_list = ast.literal_eval(poll)
    if isinstance(poll_list, dict):
        if poll_list['@name'] == key:
            return [poll_list['results']]
        return pd.NA
    if isinstance(poll_list, list):
        filtered = list(
            filter(lambda x: x['@name'] == key,
            poll_list
        ))
        return list(map(lambda x: x['results'], filtered))
    return pd.NA


df['language_poll'] = df['poll'].apply(lambda x: parse_poll(x, 'language_dependence'))

# def parse_poll(poll, key):
#     try:
#         poll_list = json.loads(poll)
#         if isinstance(poll_list, list):
#             filtered = list(
#                 filter(lambda x: x['@name'] == key,
#                 poll_list
#             ))
#             try:
#                 return list(map(lambda x: x['results'], filtered))
#             except KeyError:
#                 return [] # or pd.NA
#         return pd.NA
#     except json.JSONDecodeError:
#         return pd.NA # or some default value
# # Apply the parse poll function to the poll column with the key 'language_dependence'
# df['language_poll'] = df['poll'].apply(lambda x: parse_poll(x, 'language_dependence'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 19
#      15        return list(map(lambda x: x['results'], filtered))
#      16    return pd.NA
# ---> 19 df['language_poll'] = df['poll'].apply(lambda x: parse_poll(x, 'language_dependence'))
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:4760, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4625 def apply(
#    4626     self,
#    4627     func: AggFuncType,
#    (...)
#    4632     **kwargs,
#    4633 ) -> DataFrame | Series:
#    4634     """
#    4635     Invoke function on values of Series.
#    4636
#    (...)
#    4751     dtype: float64
#    4752     """
#    4753     return SeriesApply(
#    4754         self,
#    4755         func,
#    4756         convert_dtype=convert_dtype,
#    4757         by_row=by_row,
#    4758         args=args,
#    4759         kwargs=kwargs,
# -> 4760     ).apply()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:1207, in SeriesApply.apply(self)
#    1204     return self.apply_compat()
#    1206 # self.func is Callable
# -> 1207 return self.apply_standard()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:1287, in SeriesApply.apply_standard(self)
#    1281 # row-wise access
#    1282 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1283 # we need to give `na_action="ignore"` for categorical data.
#    1284 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1285 #  Categorical (GH51645).
#    1286 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1287 mapped = obj._map_values(
#    1288     mapper=curried, na_action=action, convert=self.convert_dtype
#    1289 )
#    1291 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1292     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1293     #  See also GH#25959 regarding EA support
#    1294     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\algorithms.py:1814, in map_array(arr, mapper, na_action, convert)
#    1812 values = arr.astype(object, copy=False)
#    1813 if na_action is None:
# -> 1814     return lib.map_infer(values, mapper, convert=convert)
#    1815 else:
#    1816     return lib.map_infer_mask(
#    1817         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1818     )
#
# File lib.pyx:2917, in pandas._libs.lib.map_infer()
#
# Cell In[32], line 19, in <lambda>(x)
#      15        return list(map(lambda x: x['results'], filtered))
#      16    return pd.NA
# ---> 19 df['language_poll'] = df['poll'].apply(lambda x: parse_poll(x, 'language_dependence'))
#
# Cell In[32], line 5, in parse_poll(poll, key)
#       4 def parse_poll(poll, key):
# ----> 5    poll_list = ast.literal_eval(poll)
#       6    if isinstance(poll_list, dict):
#       7        if poll_list['@name'] == key:
#
# File ~\anaconda3\Lib\ast.py:110, in literal_eval(node_or_string)
#     108                 return left - right
#     109     return _convert_signed_num(node)
# --> 110 return _convert(node_or_string)
#
# File ~\anaconda3\Lib\ast.py:109, in literal_eval.<locals>._convert(node)
#     107         else:
#     108             return left - right
# --> 109 return _convert_signed_num(node)
#
# File ~\anaconda3\Lib\ast.py:83, in literal_eval.<locals>._convert_signed_num(node)
#      81     else:
#      82         return - operand
# ---> 83 return _convert_num(node)
#
# File ~\anaconda3\Lib\ast.py:74, in literal_eval.<locals>._convert_num(node)
#      72 def _convert_num(node):
#      73     if not isinstance(node, Constant) or type(node.value) not in (int, float, complex):
# ---> 74         _raise_malformed_node(node)
#      75     return node.value
#
# File ~\anaconda3\Lib\ast.py:71, in literal_eval.<locals>._raise_malformed_node(node)
#      69 if lno := getattr(node, 'lineno', None):
#      70     msg += f' on line {lno}'
# ---> 71 raise ValueError(msg + f': {node!r}')
#
# ValueError: malformed node or string: <NA>

# %%
df["poll"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 119488 entries, 0 to 119487
# Series name: poll
# Non-Null Count  Dtype
# --------------  -----
# 0 non-null      object
# dtypes: object(1)
# memory usage: 933.6+ KB
